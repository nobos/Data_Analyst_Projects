# %% [markdown]
# # Рынок заведений общественного питания Москвы

# %% [markdown]
# Описание данных:
#
# <br> object_name — название объекта общественного питания;
# <br> chain — сетевой ресторан;
# <br> object_type — тип объекта общественного питания;
# <br> address — адрес;
# <br> number — количество посадочных мест.

# %%
# загрузим библиотеки:
import pandas as pd
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
# #### Шаг №1. Загрузим данные и подготовьте их к анализу

# %%
rest_data = pd.read_csv('rest_data.csv')
rest_data.sample(10)
# Out:
#            id     object_name chain object_type  \
# 1984    26492        То Да Сё    да    ресторан
# 7195   150897           Школа   нет    столовая
# 14626  219486  Бургерная ФАРШ   нет    ресторан
# 11357  189638       ЛАНЧ БОКС   нет    ресторан
# 4913    22789          Кружка    да        кафе
# 641     24514   ЗОЛОТЫЕ РУЧКИ   нет        кафе
# 6162    91156      Макдоналдс    да    ресторан
# 874     27873  Буфет при ВУЗе   нет       буфет
# 8388   157428    Мини-кофейня   нет        кафе
# 13494  200021     Мята Lounge    да        кафе
#
#                                                  address  number
# 1984   город Москва, Баррикадная улица, дом 2/1, стро...     200
# 7195   город Москва, Зоологическая улица, дом 28, стр...     140
# 14626                город Москва, улица Вавилова, дом 3      36
# 11357                город Москва, Брянская улица, дом 5      48
# 4913     город Москва, Митинская улица, дом 25, корпус 4      84
# 641            город Москва, Люблинская улица, дом 121/1      40
# 6162           город Москва, Профсоюзная улица, дом 129А     120
# 874    город Москва, Большая Переяславская улица, дом...      30
# 8388   город Москва, Краснопресненская набережная, до...       0
# 13494     город Москва, улица Космонавта Волкова, дом 6А       8

# %%
#проверим, есть ли дубликаты
rest_data[rest_data[['object_name','chain','address','number','object_type']].duplicated()].count()
# Out:
# id             82
# object_name    82
# chain          82
# object_type    82
# address        82
# number         82
# dtype: int64

# %%
#избавимся от дубликатов
rest_data = rest_data[['object_name','chain','address','number','object_type']].drop_duplicates().reset_index(drop = True)

# %%
rest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15284 entries, 0 to 15283
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   object_name  15284 non-null  object
#  1   chain        15284 non-null  object
#  2   address      15284 non-null  object
#  3   number       15284 non-null  int64
#  4   object_type  15284 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 597.2+ KB

# %%
print(rest_data['object_type'].unique())
print(rest_data['chain'].unique())
# Out:
# ['кафе' 'столовая' 'закусочная' 'предприятие быстрого обслуживания'
#  'ресторан' 'кафетерий' 'буфет' 'бар' 'магазин (отдел кулинарии)']
# ['нет' 'да']

# %%
# для удобства заменим данные из колонки chain на True и False
rest_data['chain'].replace({'да':True,'нет':False},inplace = True)

# %%
rest_data.query('chain == True')['object_name'].unique()
# Out:
# array(['ПИЦЦЕТОРИЯ', 'Брусника', 'Алло Пицца', 'Суши Wok', 'Тануки',
#        "Домино'с Пицца", 'Готика', 'Му-Му', 'Хлеб насущный', 'TAJJ MAHAL',
#        'ДАНКИН ДОНАТС', 'Вареничная №1', 'ШОКОЛАДНИЦА', 'Теремок',
#        'Хинкальная', 'Шантимель', 'ТАНУКИ', 'Шоколадница', 'МУ-МУ',
#        'Хинкальная City', 'КРУЖКА', 'СУШИ ВОК', 'ПРИМАВЕРА', 'Виктория',
#        'Пиццерия «АКАДЕМИЯ»', 'Чебуречная СССР', 'МАКДОНАЛДС',
#        'Grand Cru', 'Чайхона №1', 'Панчо Пицца', 'KFC', 'Сабвей',
#        'ресторан «Якитория»', 'Советские времена', 'Кафе «Андерсон»',
#        'Кафе «Subway»', 'Ресторан «Макдоналдс»', 'Суши Сет', 'Суши WoK',
#        'Шоколад', 'Тирольские пироги', 'Гамбринус', 'Пицца Фабрика',
#        'Subway', 'Кафе «Якитория»', 'Кафе «Тануки»', 'Сити Пицца',
#        'Кружка', 'Кофе Хаус',
#        'Кулинарная Лавка Братьев Караваевых Братья Караваевы', 'Суши Вок',
#        'Прайм', 'Пицца Экспресс', 'Шоколадница Кофе Хаус', 'Николай',
#        'Якитория', 'МАГНОЛИЯ', 'КОФЕ С СОБОЙ', 'Джаганнат', 'Волконский',
#        'MosKalyan', 'Гино-но-таки', 'Макдоналдс', 'Тратория Semplice',
#        'Ньокки', 'Хижина', 'Додо Пицца', 'Крошка Картошка', 'Бургер Кинг',
#        'Суши WOK', 'Папа Джонс', 'Кондитерская Волконский',
#        'Бар- буфет «Николай»', 'Ресторан «Тануки»', 'Две палочки',
#        'Джон Джоли', 'Ваби-Саби', 'Кофемания', 'Простые Вещи',
#        'Павлин-Мавлин', 'Кафе «Чайхана Тапчан»', 'Штолле', 'Суши сет',
#        'Кофе с собой', 'Бабай Клаб', 'Андерсон', 'КОФЕМАНИЯ',
#        'КОФЕ ХАУС. ЭКСПРЕССО И КАПУЧИНО БАР', 'КАКТУС', 'Темпл бар',
#        'Хлеб&Co', 'Кофе-Бин', 'Французская выпечка',
#        'Кофейня «Кофе Хаус»', 'Планета Суши', 'Де Марко',
#        'Ресторан «Илья Муромец»', 'Ресторан «Корчма Тарас Бульба»',
#        'Кофейня «Шоколадница»', 'Стейк Хаус ГУДМАН', 'ИЛЬ ПАТИО',
#        'Иль-патио', 'ЯКИТОРИЯ', 'Мюнгер', 'БОТИК ПЕТРА',
#        'кафе «Папа Джонс»', 'Кафе «Штолле»', 'Чин Чин', 'ПРАВDА Кофе',
#        'Сити', 'Krispy Creme', 'Prime Прайм стар', 'Азбука Вкуса',
#        'Ресторан «Якитория»', 'КАФЕ «ШТОЛЛЕ»', 'РЕСТОРАН «ДЖОН ДЖОЛИ»',
#        'Ресторан «ТАНУКИ»', 'КОФЕ ХАУС', 'РЕСТОРАН «Тануки»', 'ПИВКО',
#        'Додо пицца', 'Пиццерия «Папа Джонс»', 'Ресторан «Брудер»',
#        'ПРАЙМ', 'ДЖОН ДЖОЛИ', 'Мимино', 'Кофепорт',
#        'Кафе «Пицца Фабрика»', 'Прайм стар', 'Цинандали Хинкальная',
#        'Иль Форно', 'Travelers Coffee', 'Рецептор', 'СушиШоп',
#        'Кофе-Хаус', 'Баскин Роббинс', 'Барашка', 'КОРЧМА «ТАРАС БУЛЬБА»',
#        'Кафе «Шоколадница»', 'Пицца Хат', 'Мята Lounge', 'Costa Coffee',
#        'Илья Муромец', 'Ёрш', 'СтардогS', 'КОРЧМА ТАРАС БУЛЬБА',
#        'UPSIDE DOWN CAKE', 'Кафе Пекарня Хачапури',
#        'Домашнее Кафе сеть городских кафе', 'Ресторан Тануки',
#        'Бар-буфет Николай', 'Добрынинский и партнёры',
#        'КОФЕЙНЯ «ДЕ МАРКО»', 'Менза', 'Тапчан', 'Колбасофф',
#        'Крепери де пари', "Домино'с пицца", 'БРАВА Коста кофе',
#        'Старбакс Starbucks', 'АндерСон', 'Венеция', 'Жан Жак', 'Гурмания',
#        'Кулинарная лавка братьев Караваевых', 'Кафе «Тапчан»',
#        'Ресторан «Ньокки»', 'Bierloga', 'Штирбирлиц', 'Маки-Маки',
#        'ХАЧАПУРИ', 'В&В Бургер', 'Прайм Стар', 'Jeffreys coffee',
#        'Travelers Coffe', 'АКАДЕМИЯ', 'Дабл Би', 'Иль Патио',
#        'ЗОЛОТАЯ ВОБЛА', 'ТЕРЕМОК', 'Корчма Тарас Бульба', 'АЛЛО ПИЦЦА',
#        'ПИЛЗНЕР', 'Траттория Примавера', 'ПРАЙМкафе Прайм стар',
#        "Пиццерия «Домино'с Пицца»", 'Кафе «Суши Сет»', 'Коста Кофе',
#        'СУШИ WOK', 'РЕСТОРАН «ТАНУКИ»', 'Перекресток', 'Starbucks',
#        'Руккола', 'Иль Патио Планета Суши', 'Кафе «Starbucks»',
#        'Шантимель (кондитерские)', 'Милано пицца',
#        'Ресторан «Джон Джоли»', 'Зодиак', 'Ресторан «Ёрш»', 'Торро Гриль',
#        'ФИТНЕС-БАР «WORLD CLASS»', 'Роллофф', 'Кафе «Кулинарное бюро»',
#        'БУРГЕР КИНГ', 'Билла', 'УРЮК', 'Темпл Бар', 'Кофейня «Старбакс»',
#        'Кафе «Кружка»', 'Пицца экспресс', 'Tokyo bay',
#        'Пиццерия «ПАПА ДЖОНС»', 'КУЛИНАРНОЕ БЮРО', 'Пиппони',
#        'Пицца Пипони', 'Золотая вобла', 'ДЕТСКОЕ КАФЕ «АНДЕРСОН»',
#        'Кулинарное бюро', 'КАФЕ «Хлеб насущный»', 'ПИЦЦЕРИЯ «Папа Джонс»',
#        'КАФЕ «Андерсон»', 'Кулинарное бюро Китчен', 'Сытая Утка',
#        'Икура Паб', 'Сварня', 'Пиццетория', 'ДЕТСКИЙ КЛУБ «АНДЕРСОН»',
#        'Пиццерия Пиу дель Чибо',
#        'Предприятие быстрого обслуживания «Бургер Кинг»',
#        'Предприятие быстрого обслуживания «Крошка Картошка»',
#        'Предприятие быстрого обслуживания «Макдоналдс»',
#        'Предприятие быстрого обслуживания «Теремок»', 'Ичибан Боши',
#        'Макс Бреннер', 'Бутчер Бизон', 'Магбургер АЗС №16',
#        'Магазин-кулинария «Суши Сет»', 'Магбургер АЗС №17',
#        'Кондитерская-пекарня Волконский', 'Му-му', 'IL Forno Иль Форно',
#        'Хлеб Насущный', 'Кафе «Prime» Прайм стар', 'То Да Сё',
#        'Пицца Pomodoro', 'Бургер Кинг Burger King',
#        'Чешская пивная «Козловица»', 'Ресторан Джон Джоли',
#        'Простые вещи', 'Грабли', 'VietCafe Вьеткафе', 'Оникс',
#        'Пицца Pomodoro и Суши Дзен', 'Вьеткафе', 'Да Пино',
#        'Старина Миллер', 'Кафе Рецептор', 'Якитория и Ян Примус',
#        'СТАРИНА МЮЛЛЕР Старина Миллер', 'Кафе Кофемания', 'Хинкальная №1',
#        'Пронто', 'Пицца «Паоло»', 'Лепешка', 'Чешская пивная «Пилзнер»',
#        'ПИРОГИ ШТОЛЛЕ', 'Крепери де Пари', 'Гурман', 'ТЕРРИТОРИЯ ЯСЕНЕВО',
#        'Сабвей СушиВок', 'Городские автокофейни', 'ВГости. Урюк',
#        'Порто Мальтезе', 'Мимино Хинкальная', 'Квартира 44',
#        'Хинкальная КИНТО', 'КОЛБАСОФФ', 'Урюк',
#        'Американ Сити Пицца ЦЕХ ПО ИЗГОТОВЛЕНИЮ ПИЦЦЫ',
#        'РЕСТОРАН «Чайхона №1»', 'БАР Азбука Вкуса', 'КАФЕ «Шоколадница»',
#        'Суп Кафе', 'Ресторан «Florentini»', 'Upside Down Cake',
#        'Поль Бейкери', 'кафе «Шоколадница»', 'Кафе «Му-Му»',
#        'GlowSubs Sandwiches', 'Ми Пьяче', 'Кафе «Хинкальная»',
#        'Закусочная «СушиШоп»', 'Ресторан «Территория»', 'Кафе «KFC»',
#        'Кафе «Пицца Хат»', 'Пиццерия Донателло',
#        'Закусочная «Американ Сити Пицца»',
#        'Предприятие быстрого обслуживания «СушиШоп»',
#        'Кафе «PRIME» Прайм стар', 'Нияма Пицца Пи', 'Кафе «Ваби-Саби»',
#        'Кафе «Марукамэ»', 'Кафе Чайхона №1', 'Бир хаус', 'САБВЕЙ',
#        'Хачапури', 'СПБ', 'Кебаб хаус', 'Прайм-кафе', 'PAUL Поль',
#        'ВЕНЕЦИЯ', 'ШАШЛЫК-МАШЛЫК', 'ГЕНАЦВАЛИ', 'Территория TIMBIGFAMILY',
#        'Территория', 'Да Пино (Da Pino)',
#        'Кулинарная лавка братьев Караваевых Братья Караваевы',
#        'Ресторан «Золотая Вобла»', 'Кафе PRIME Прайм стар',
#        'Граци рагацци Зю Кафе', 'Виват-Пицца', 'Ресторан «Вьеткафе»',
#        'Пироговая Штолле', 'Сабвей Subway', 'Starlite Diner',
#        'Прайм-кафе Прайм стар', 'ресторан «Брудер»', 'Старбакс', 'ПРОНТО',
#        'РЕСТОРАН «УРЮК»', 'Krispy Krem', 'ГРАБЛИ', 'Кофе Хаус,Экспресс',
#        'Ростикс KFC', 'Ресторан «ИЛЬ ПАТИО»', 'Ресторан Маки-Маки',
#        'КАФЕ «МУ-МУ»', 'Кофейня Шоколадница', 'Кафе Пронто',
#        'Кафе Якитория', 'Кофетун', 'ТАШИР ПИЦЦА', 'Ресторан Хинкальная',
#        'Закусочная KFC', 'Елки-Палки', 'Кофейня ШОКОЛАДНИЦА',
#        'Кафе КОФЕ ТУН', 'Метро К&К', 'Тамаси Суши', 'Burger Club',
#        'ФАНТОЦЦИ РУС', 'КАФЕ «ЯКИТОРИЯ»', 'Кафе «Урюк» Хивинская чайхона',
#        'Ресторан «Пронто»', 'Изба', 'Воккер', 'Нияма', 'Ганс и Марта',
#        'Кафе «Поль Бейкери»', 'Кафе «Сабвей» Старбакс',
#        'KFC Волгоградский', 'Кофе', 'Ресторан «Чайхона №1»',
#        'Кафе «Теремок»', 'Ливан-хаус', 'Крошка картошка', 'Лето',
#        'Кафе «АндерСон»', 'Суши бар «Маки-маки»', 'ЯММИ МИКС', 'Брудер',
#        'Бургер кинг', 'Баракат', 'Кафе при АЗС', 'Урюк Вавилова',
#        'SUBWAY', 'Кафе теремок', 'Кулинарное бюро Kitchen',
#        'МОСКВА - МАКДОНАЛДС', 'ТЕРЕМОК ИНВЕСТ', 'Ресторан«ВьетКафе»',
#        'НИЯМА', 'Кафе Космик', 'СушиМан', 'Кафе шоколад', 'ЯПОША',
#        'МАКИ-МАКИ', 'Примавера', 'Кофе тун', 'Барбарис', 'Yogurt Frenzy',
#        'Ташир пицца', 'Bocconcino', 'ПОМИДОР', 'Дюшес', 'Маки-маки',
#        'Планета суши', 'Чайхона №1 Бутово', 'Кафе «То Да Сё»',
#        'кафе «Старбакс»', 'Урожай', 'Ресторан «Ян Примус»', 'ШВАРЦВАЛЬД',
#        'TUTTI FRUTTI FROZEN YOGURT', 'Данкин Донатс', 'Кафе «Нияма»',
#        'Кафе «Менза»', 'Ресторан «Джардино Да Пино»', 'Кафе «МЕЛЕНКА»',
#        'Кафе «Кофейня Старбакс»', 'Ресторан «Колбасофф»',
#        'КАФЕ МАКДОНАЛДС', 'КАФЕ «Теремок»', 'КАФЕ KFC', 'Сбарро',
#        'КАФЕ «МАКДОНАЛДС»', 'КАФЕ «Восточный базар»', 'КАФЕ Кофе-Хаус',
#        'КАФЕ Starbucks', 'РЕСТОРАН «Космик»', 'КАРО', 'ХИНКАЛЬНАЯ',
#        'ПБО «KFC Покрышкина»', 'кафе «Му-Му»', 'Кофейня «СТАРБАКС КОФЕ»',
#        'Ресторан «Планета Суши»', 'White Rabbite (Белый кролик)',
#        'БАКИНСКИЙ БУЛЬВАР', 'Ян Примус', 'Кафе МУ-МУ',
#        'Кафе «Prime» (Прайм стар)', 'Healthy Food', 'Sushilka',
#        'Кебаб Хаус', 'Coffeeshop Company', 'Теремок-Инвест',
#        'Кафе «МАКДОНАЛДС»', 'ИЛЬ ФОРНО', 'Maki Maki',
#        'РЕСТОРАН«МАКДОНАЛДС»', 'ЧАЙХОНА №1', 'РЕСТОРАН «ЧАЙХОНА №1»',
#        'КОФЕЙНЯ «ШОКОЛАДНИЦА»', 'АНДЕРСОН', 'КАФЕ «ТЕРЕМОК»',
#        'СТЕЙК-ХАУС ГУДМАН', 'МЕНЗА', 'Барбекю', 'Обжорный ряд', 'Космик',
#        'Ресторан «БРУДЕР»', 'Тайм Авеню', 'Братья Караваевы',
#        'СтардогS и шаурма', 'Wok & Box', 'ПивКо',
#        'Кафе при АЗС Газпромнефть', 'Старбакс Кофе', 'Бар Боулинг-Космик',
#        'Академия', 'Ресторан «Темпл Бар»', 'Закусочная «Бургер Кинг»',
#        'Ресторан «Чайхана Урюк»', 'Прайм Стар кафе',
#        'Кофе с собой Gate 42', 'Кафе-закусочная «Бургер Кинг»',
#        'Ресторан «ЯКИТОРИЯ»', 'Кафе «Торнадо»', 'Магбургер', 'КОФЕПОРТ',
#        'Ресторан «Теремок»', 'Кафе «Макдоналдс»',
#        'Ресторан «Бакинский бульвар»', 'Бакинский бульвар',
#        "Предприятие быстрого обслуживания «Домино'с Пицца»",
#        'Кафе «Прайм Стар»', 'Кафе «SUBWAY»',
#        'Предприятие быстрого обслуживания «Бенто WOK»',
#        'Предприятие быстрого обслуживания «KFC»', 'Бургер клаб',
#        'Кафе «Кофе Хаус»', 'Кафе при АЗС «BP»', 'Wokker', 'АРИАНА',
#        'Кафе «Суши Вок»', 'Кафе «Бургер Кинг»', 'ПАПА ДЖОНС ПИЦЦА',
#        'Закусочная «Теремок»', 'Закусочная «Крошка Картошка»',
#        'Ресторан «Иль Патио»', 'Спорт-бар «Космик»', 'Ресторан «Космик»',
#        'Ресторан японской кухни «Маки-Маки»', 'Детское кафе «Космик»',
#        'Кафе ПРОНТО', 'Кофейня «Кофе хаус»', 'Ванвок', 'Шикари Иль Патио',
#        'Кафе «Данкин Донатс»', 'Ресторан «Бургер Кинг»',
#        'Кафе «Крошка Картошка»', 'Закусочная «KFC»',
#        'Закусочная «Пицца Хат»', 'Кафе «Costa coffee»', 'Каффе «Wokker»',
#        'Семейный ресторан «Космик»', 'Кафе Иль Патио «Il Patio»',
#        'Ресторан «Урюк»', 'Кофейня «Дабл Би»', 'Ресторан KFC',
#        'Ресторан быстрого питания «Крошка Картошка»', 'кафе «Нияма»',
#        'Starbucks кофе', 'МИ ПЬЯЧЕ', 'Пражечка',
#        'Павлин Мавлин Чайхона №1', 'Блинная', 'Correas',
#        'Мистер Картошка', 'Кафе «Сим-Сим»', 'Кафе «Му-му»',
#        'Pizengof99 СПБ', 'Меленка', 'Югос', 'Марчеллис',
#        'Кафе Песто и Митлес', 'Ресторан «Вареничная №1»', 'Молли гвинз',
#        'ВьетКафе', 'Шоколадница Кофемания', 'Дорогая я перезвоню',
#        'M Cafe Хинкальная', 'Marrakesh Хинкальная',
#        'Кофейня Кофемания, пиццерия Бармалини',
#        'Кофешоп Coffeeshop Company', 'Гудман Гудвин', 'Гудман',
#        'Torro Grill Торро Гриль', 'Ресторан Торро Гриль',
#        'Кафе «Старбакс»', 'The Terrace', 'Ваби-саби', 'Бир Хаус Паб',
#        'CORREAS', 'Вlack Burger Чайхона №1', 'Пончиковое кафе ИКЕА Ikea',
#        'Ресторан ИКЕА Ikea', 'Black & White', 'Пиццерия «Додо Пицца»',
#        'Роснефть', 'Upside Down', 'ПБО «KFC»', 'ПБО «Теремок»',
#        'Starbucks, СТАРБАКС КОФЕ', 'КОФЕЙНЯ «Costa Coffee»',
#        "ДОМИНО'С ПИЦЦА", 'Cookhouse', 'Dunkin Donuts',
#        'МСК Московская сеть кальянных', 'Братья Караваевых',
#        'Кафе Бургер Кинг', 'Кафе «ТО ДА СЁ»',
#        'Предприятие быстрого обслуживания «Магбургер»',
#        'Кафе «Баскин Роббинс»', 'Ресторан «БУРГЕР КИНГ»',
#        'Кафе БУРГЕР КИНГ', 'Пицца Паоло', 'COFIX', 'Пикколо', 'Пицца хат',
#        'Cofix', 'Милти', 'Сеть магазинов «Суши Wok»', 'Васаби',
#        'Грузинская кухня ЭZО Хинкальная', 'Кафе быстрого питания Му-му',
#        'Ресторан ТАНУКИ', 'Кафе Суши Wok', 'Хачапури, Одесса -мама',
#        'TGI FRIDAYS', 'Deli by Prime Прайм-кафе', 'Пицерия «Папа Джонс»',
#        'HEALTHY Food', 'Дабл Би блэк', 'Азбука вкуса', 'МИМИНО',
#        'Точка продажи готовой еды Милти',
#        'Предприятие быстрого обслуживания «ДОДО Пицца»',
#        'Суши «Маки-Маки»', 'Семейное кафе и кондитерская «Андерсон»',
#        'Пиццерия Папа Джонс', 'GRAND УРЮК', 'Кафе Волконский пекарня',
#        'Стардогs', 'Panda Express', 'Кафе «БУРГЕР КИНГ»',
#        'АВ-Дейли Азбука Вкуса', 'ШАНТИМЕЛЬ', 'Healthy food',
#        'Ирландский Паб', 'Ресторан «KFC»',
#        'Кафе мороженного «Tutti Frutti»', 'Кафе «Суши Wok»',
#        'Бар «Суши Wok»', 'Япоша', 'КУЛИНАРНАЯ ЛАВКА БРАТЬЕВ КАРАВАЕВЫХ',
#        "Ресторан «Домино'с Пицца»", 'Tutti frutti', 'Кафе «Папа Джонс»',
#        'ПАПА ДЖОНС', 'Кафе Prime Прайм стар Прайм-кафе',
#        'PRIME Прайм стар Прайм-кафе', 'Суши вок', "Кафе «Домино'с Пицца»",
#        'КАФЕ-ПЕКАРЕЯ «ВОЛКОНСКИЙ»', 'Нияма. Пицца Пи', 'Алло Пицца 2',
#        'БИСТРО ПРОНТО', 'ШТОЛЛЕ', 'Ливан-Хаус', 'Зю Кафе',
#        'Восточный базар', 'Сказка', 'Ресторан «Хинкальная»',
#        'Jeffreys Coffee', 'Ресторан «Пицца Хат»', 'Вкусняшка',
#        'МагБургер', 'Грузинские каникулы Барбарис', 'Стардогс СтардогS',
#        'Суши тун, Хруст pizza, Кофе тун', 'Кофе с собой «Кофейня»',
#        'Пиццерия «Пицца Паоло»', 'Кафе при АЗС Лукойл',
#        'Лукойл-Центрнефтьпродукт', 'FRIDAYS', 'TGI Fridays', 'Мираторг',
#        'Закусочная «Баскин Роббинс & Стардогс»', 'Бенто WOK',
#        'Кафе «Иль Патио»', 'Bubbleology', 'Starbucks Старбакс',
#        'Бодрый день Кофе с собой', 'ДоДо Пицца', 'ДОДО ПИЦЦА',
#        'ДОДО Пицца', 'BooBo', 'Кальянная Мята Lounge',
#        'Кальян-бар «Мята Lounge»', 'Кальян- бар «Мята Lounge»',
#        'Паб Кружка', 'БРУСНИКА', 'Luciano', 'Пиццерия «Пицца Хат»',
#        'Лукойл', 'Мята Lounge Шаболовка', 'Кальянная F-lounge', 'МИЛТИ',
#        'ПРАЙМ СТАР', 'МСК Московская сеть кальянных на Шаболовке',
#        'Семейное кафе Андерсон',
#        '«Кафе «Кулинарная лавка братьев Караваевых»»',
#        'Кафе «Кулинарная лавка братьев Караваевых»',
#        '«Кафе «Кулинарная лавка братьев Караваевых»',
#        "Домино'с Пицца Domino,s Pizza", 'Чешская пивная ПИЛЗНЕР',
#        'Beverly Hills Diner', 'Кафе Штолле',
#        'Предприятие быстрого питания «Крошка Картошка»', 'Florentini',
#        'Кондитерия Тирольские пироги', 'LAVKALAVKA', 'Хлебница пекарня',
#        'Кальян-бар MosKalyan', 'Анти-кафе кальянная «MosKalyan»',
#        'Ботик Петра', 'Советские времена Чебуречная СССР', 'ДоДо пицца',
#        'Мята Lounge Автозаводская', 'Osteria Mario', 'МЯСОROOB',
#        'МясоROOB', 'Газпромнефтьцентр', 'ДВЕ ПАЛОЧКИ', 'ХЛЕБ НАСУЩНЫЙ',
#        'ЯКИТОРИЯ И СПОРТ БАР', 'Японский ресторан «Ваби-Саби»',
#        'Goodman Гудман', 'PRIME STAR Прайм стар', 'Праймстар',
#        'CoffeeShop', 'My box', 'Vanwok Ванвок', 'Van Wok Ванвок',
#        'ББ энд БУРГЕРС В&В Бургер', 'КРОШКА КАРТОШКА',
#        'Закусочная «СтардогS»', 'Сувлаки', 'Бургер Клаб', 'Суши тун',
#        'Кофе с Собой', 'Пицца ПИПОНИ', 'Пицца Паоло и Бенто WOK',
#        'STARBUCKS COFFEE', 'Кофемания Starbucks', 'Movenpick',
#        'РОСТИКС KFC', 'Fridays KFC', 'Ресторан быстрого питания KFC',
#        'ВОККЕР', 'Marmalato', 'Предприятие быстрого обслуживания «Милти»',
#        'Дабл би', 'ДОДО пицца', 'Магазин готовой еды «Милти»',
#        'Готовые блюда Милти', 'Мята lounge', 'Лаундж-бар «Мята Lounge»',
#        'Бар Мята Lounge', 'Мята Lounge Октябрьская',
#        'Кальянная «Мята Lounge»', 'Мята'], dtype=object)

# %% [markdown]
# Похоже среди сетевых заведени очень много проблем с названиями - некоторые названия большими буквами, у многих в начале приписка - кафе, бар, ресторан и прочее. Нужно избавиться от этого.

# %%
#приведем названия к нижнему регистру
rest_data['object_name'] = rest_data['object_name'].apply(lambda x: x.lower())

# %%
object_type_dict = rest_data['object_type'].unique()
add_to_dict = np.array(['«','»','-','ресторан японской кухни','японский ресторан','кофейня','кафе-закусочная','ресторан быстрого питания','семейное кафе и кондитерская','кафе мороженного','семейное кафе','закусочная','пиццерия','кальянная','предприятие быстрого питания','кальян-бар','анти-кафе кальянная','японский ресторан'])
object_type_dict = np.append(object_type_dict,add_to_dict)
object_type_dict
# Out:
# array(['кафе', 'столовая', 'закусочная',
#        'предприятие быстрого обслуживания', 'ресторан', 'кафетерий',
#        'буфет', 'бар', 'магазин (отдел кулинарии)', '«', '»', '-',
#        'ресторан японской кухни', 'японский ресторан', 'кофейня',
#        'кафе-закусочная', 'ресторан быстрого питания',
#        'семейное кафе и кондитерская', 'кафе мороженного',
#        'семейное кафе', 'закусочная', 'пиццерия', 'кальянная',
#        'предприятие быстрого питания', 'кальян-бар',
#        'анти-кафе кальянная', 'японский ресторан'], dtype=object)

# %%
#напишем функцию, которая очистит названия от лишних элементов
def cleaner(text):
    global object_type_dict
    for d in object_type_dict:
        while d in text:
            text = text.replace(d,'')
    return text.strip()

# %%
#применим функцию
rest_data['new_name'] = rest_data['object_name'].apply(cleaner)

# %%
rest_data.query('chain == True')['new_name'].unique()
# не идеально, но лучше чем было
# Out:
# array(['пиццетория', 'брусника', 'алло пицца', 'суши wok', 'тануки',
#        "домино'с пицца", 'готика', 'муму', 'хлеб насущный', 'tajj mahal',
#        'данкин донатс', 'вареничная №1', 'шоколадница', 'теремок',
#        'хинкальная', 'шантимель', 'хинкальная city', 'кружка', 'суши вок',
#        'примавера', 'виктория', 'академия', 'чебуречная ссср',
#        'макдоналдс', 'grand cru', 'чайхона №1', 'панчо пицца', 'kfc',
#        'сабвей', 'якитория', 'советские времена', 'андерсон', 'subway',
#        'суши сет', 'шоколад', 'тирольские пироги', 'гамбринус',
#        'пицца фабрика', 'сити пицца', 'кофе хаус',
#        'кулинарная лавка братьев караваевых братья караваевы', 'прайм',
#        'пицца экспресс', 'шоколадница кофе хаус', 'николай', 'магнолия',
#        'кофе с собой', 'джаганнат', 'волконский', 'moskalyan',
#        'гинонотаки', 'тратория semplice', 'ньокки', 'хижина',
#        'додо пицца', 'крошка картошка', 'бургер кинг', 'папа джонс',
#        'кондитерская волконский', 'две палочки', 'джон джоли', 'вабисаби',
#        'кофемания', 'простые вещи', 'павлинмавлин', 'чайхана тапчан',
#        'штолле', 'бабай клаб', 'кофе хаус. экспрессо и капучино',
#        'кактус', 'темпл', 'хлеб&co', 'кофебин', 'французская выпечка',
#        'планета суши', 'де марко', 'илья муромец', 'корчма тарас бульба',
#        'стейк хаус гудман', 'иль патио', 'ильпатио', 'мюнгер',
#        'ботик петра', 'чин чин', 'правdа кофе', 'сити', 'krispy creme',
#        'prime прайм стар', 'азбука вкуса', 'пивко', 'брудер', 'мимино',
#        'кофепорт', 'прайм стар', 'цинандали хинкальная', 'иль форно',
#        'travelers coffee', 'рецептор', 'сушишоп', 'кофехаус',
#        'баскин роббинс', 'ашка', 'пицца хат', 'мята lounge',
#        'costa coffee', 'ёрш', 'стардогs', 'upside down cake',
#        'пекарня хачапури', 'домашнее  сеть городских',
#        'добрынинский и партнёры', 'менза', 'тапчан', 'колбасофф',
#        'крепери де пари', 'брава коста кофе', 'старбакс starbucks',
#        'венеция', 'жан жак', 'гурмания',
#        'кулинарная лавка братьев караваевых', 'bierloga', 'штирбирлиц',
#        'макимаки', 'хачапури', 'в&в бургер', 'jeffreys coffee',
#        'travelers coffe', 'дабл би', 'золотая вобла', 'пилзнер',
#        'траттория примавера', 'прайм прайм стар', 'коста кофе',
#        'перекресток', 'starbucks', 'руккола', 'иль патио планета суши',
#        'шантимель (кондитерские)', 'милано пицца', 'зодиак',
#        'торро гриль', 'фитнес world class', 'роллофф', 'кулинарное бюро',
#        'билла', 'урюк', 'старбакс', 'tokyo bay', 'пиппони',
#        'пицца пипони', 'детское  андерсон', 'кулинарное бюро китчен',
#        'сытая утка', 'икура паб', 'сварня', 'детский клуб андерсон',
#        'пиу дель чибо', 'ичибан боши', 'макс бреннер', 'бутчер бизон',
#        'магбургер азс №16', 'магазинкулинария суши сет',
#        'магбургер азс №17', 'кондитерскаяпекарня волконский',
#        'il forno иль форно', 'то да сё', 'пицца pomodoro',
#        'бургер кинг burger king', 'чешская пивная козловица', 'грабли',
#        'vietcafe вьет', 'оникс', 'пицца pomodoro и суши дзен', 'вьет',
#        'да пино', 'старина миллер', 'якитория и ян примус',
#        'старина мюллер старина миллер', 'хинкальная №1', 'пронто',
#        'пицца паоло', 'лепешка', 'чешская пивная пилзнер',
#        'пироги штолле', 'гурман', 'территория ясенево', 'сабвей сушивок',
#        'городские автокофейни', 'вгости. урюк', 'порто мальтезе',
#        'мимино хинкальная', 'квартира 44', 'хинкальная кинто',
#        'американ сити пицца цех по изготовлению пиццы', 'суп',
#        'florentini', 'поль бейкери', 'glowsubs sandwiches', 'ми пьяче',
#        'территория', 'донателло', 'американ сити пицца', 'нияма пицца пи',
#        'марукамэ', 'бир хаус', 'спб', 'кебаб хаус', 'paul поль',
#        'шашлыкмашлык', 'генацвали', 'территория timbigfamily',
#        'да пино (da pino)', 'граци рагацци зю', 'виватпицца',
#        'пироговая штолле', 'сабвей subway', 'starlite diner',
#        'krispy krem', 'кофе хаус,экспресс', 'ростикс kfc', 'кофетун',
#        'ташир пицца', 'елкипалки', 'кофе тун', 'метро к&к', 'тамаси суши',
#        'burger club', 'фантоцци рус', 'урюк хивинская чайхона', 'изба',
#        'воккер', 'нияма', 'ганс и марта', 'сабвей старбакс',
#        'kfc волгоградский', 'кофе', 'ливанхаус', 'лето', 'суши  макимаки',
#        'ямми микс', 'акат', 'при азс', 'урюк вавилова',
#        'кулинарное бюро kitchen', 'москва  макдоналдс', 'теремок инвест',
#        'космик', 'сушиман', 'япоша', 'ис', 'yogurt frenzy', 'bocconcino',
#        'помидор', 'дюшес', 'чайхона №1 бутово', 'урожай', 'ян примус',
#        'шварцвальд', 'tutti frutti frozen yogurt', 'джардино да пино',
#        'меленка', 'сро', 'восточный базар', 'каро', 'пбо kfc покрышкина',
#        'старбакс кофе', 'white rabbite (белый кролик)',
#        'бакинский бульвар', 'prime (прайм стар)', 'healthy food',
#        'sushilka', 'coffeeshop company', 'теремокинвест', 'maki maki',
#        'стейкхаус гудман', 'бекю', 'обжорный ряд', 'тайм авеню',
#        'братья караваевы', 'стардогs и шаурма', 'wok & box',
#        'при азс газпромнефть', 'боулингкосмик', 'чайхана урюк',
#        'кофе с собой gate 42', 'торнадо', 'магбургер', 'бенто wok',
#        'бургер клаб', 'при азс bp', 'wokker', 'ариана',
#        'папа джонс пицца', 'спорт космик', 'японской кухни макимаки',
#        'детское  космик', 'ванвок', 'шикари иль патио', 'каффе wokker',
#        'семейный  космик', 'иль патио il patio',
#        'быстрого питания крошка картошка', 'starbucks кофе', 'пражечка',
#        'павлин мавлин чайхона №1', 'блинная', 'correas',
#        'мистер картошка', 'симсим', 'pizengof99 спб', 'югос', 'марчеллис',
#        'песто и митлес', 'молли гвинз', 'шоколадница кофемания',
#        'дорогая я перезвоню', 'm cafe хинкальная', 'marrakesh хинкальная',
#        'кофемания,  малини', 'кофешоп coffeeshop company',
#        'гудман гудвин', 'гудман', 'torro grill торро гриль',
#        'the terrace', 'бир хаус паб', 'вlack burger чайхона №1',
#        'пончиковое  икеа ikea', 'икеа ikea', 'black & white', 'роснефть',
#        'upside down', 'пбо kfc', 'пбо теремок',
#        'starbucks, старбакс кофе', 'cookhouse', 'dunkin donuts',
#        'мск московская сеть кальянных', 'братья караваевых', 'cofix',
#        'пикколо', 'милти', 'сеть магазинов суши wok', 'васаби',
#        'грузинская кухня эzо хинкальная', 'быстрого питания муму',
#        'хачапури, одесса мама', 'tgi fridays', 'deli by prime прайм',
#        'пицерия папа джонс', 'дабл би блэк',
#        'точка продажи готовой еды милти', 'суши макимаки',
#        'семейное  и кондитерская андерсон', 'grand урюк',
#        'волконский пекарня', 'panda express', 'авдейли азбука вкуса',
#        'ирландский паб', 'мороженного tutti frutti', 'tutti frutti',
#        'prime прайм стар прайм', 'пекарея волконский', 'нияма. пицца пи',
#        'алло пицца 2', 'бистро пронто', 'зю', 'сказка', 'вкусняшка',
#        'грузинские каникулы ис', 'стардогс стардогs',
#        'суши тун, хруст pizza, кофе тун', 'при азс лукойл',
#        'лукойлцентрнефтьпродукт', 'fridays', 'мираторг',
#        'баскин роббинс & стардогс', 'bubbleology', 'starbucks старбакс',
#        'бодрый день кофе с собой', 'boobo', 'кальян мята lounge',
#        'кальян  мята lounge', 'паб кружка', 'luciano', 'лукойл',
#        'мята lounge шаболовка', 'flounge',
#        'мск московская сеть кальянных на шаболовке', 'семейное  андерсон',
#        "домино'с пицца domino,s pizza", 'beverly hills diner',
#        'кондитерия тирольские пироги', 'lavkalavka', 'хлебница пекарня',
#        'кальян moskalyan', 'анти  moskalyan',
#        'советские времена чебуречная ссср', 'мята lounge автозаводская',
#        'osteria mario', 'мясоroob', 'газпромнефтьцентр',
#        'якитория и спорт', 'японский  вабисаби', 'goodman гудман',
#        'prime star прайм стар', 'праймстар', 'coffeeshop', 'my box',
#        'vanwok ванвок', 'van wok ванвок', 'бб энд бургерс в&в бургер',
#        'сувлаки', 'суши тун', 'пицца паоло и бенто wok',
#        'starbucks coffee', 'кофемания starbucks', 'movenpick',
#        'fridays kfc', 'быстрого питания kfc', 'marmalato',
#        'магазин готовой еды милти', 'готовые блюда милти',
#        'лаундж мята lounge', 'мята lounge октябрьская', 'мята'],
#       dtype=object)

# %%
rest_data.query('new_name == ""')
# 787 no-name заведений от которых придётся избавиться (5%)
# Out:
#       object_name  chain                                            address  \
# 20           кафе  False            город Москва, Алтайская улица, дом 33/7
# 61       столовая  False              город Москва, Бабаевская улица, дом 3
# 173         буфет  False  город Москва, проспект Вернадского, дом 86, ст...
# 238          кафе  False       город Москва, улица Бориса Галушкина, дом 26
# 245         буфет  False     город Москва, улица Героев Панфиловцев, дом 51
# ...           ...    ...                                                ...
# 14927        кафе  False   город Москва, Береговой проезд, дом 5А, корпус 1
# 14928     кофейня  False   город Москва, Береговой проезд, дом 5А, корпус 1
# 14931  закусочная  False  город Москва, поселение Сосенское, посёлок Ком...
# 14934        кафе  False  город Москва, Люблинская улица, владение 60, с...
# 14937     кофейня  False  город Москва, поселение Щаповское, улица Евген...
#
#        number object_type new_name
# 20         30        кафе
# 61         90    столовая
# 173        40       буфет
# 238        45    столовая
# 245        20       буфет
# ...       ...         ...      ...
# 14927       2        кафе
# 14928       4        кафе
# 14931       0  закусочная
# 14934      20        кафе
# 14937      16   кафетерий
#
# [807 rows x 6 columns]

# %%
rest_data = rest_data.query('new_name != ""').reset_index(drop=True)
rest_data.sample(5)
# Out:
#                    object_name  chain  \
# 6927              гбоу сош 556  False
# 9459  буфет «булгаковский дом»  False
# 4653  столовая гбоу сош № 1538  False
# 5371                      соки  False
# 818           кафе «americano»  False
#
#                                                 address  number object_type  \
# 6927      город Москва, Днепропетровская улица, дом 33А     240    столовая
# 9459        город Москва, Большая Садовая улица, дом 10       4       буфет
# 4653  город Москва, Новотушинский проезд, дом 8, кор...     240    столовая
# 5371    город Москва, Большая Семёновская улица, дом 16       0   кафетерий
# 818   город Москва, Малый Козихинский переулок, дом ...      30    ресторан
#
#               new_name
# 6927      гбоу сош 556
# 9459  булгаковский дом
# 4653   гбоу сош № 1538
# 5371              соки
# 818          americano

# %% [markdown]
# Данные пришлось немного обработать, в целом теперь с ними можно работать

# %% [markdown]
# ##### Шаг №2. Анализ данных

# %%
# Исследуем соотношение видов объектов общественного питания по количеству.

object_types = rest_data.groupby('object_type',as_index=False).object_name.count().sort_values(by='object_name')
fig = px.bar(object_types, x='object_type', y='object_name',title='Виды объектов общественного питания')
fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False)
fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <div>
#
#
#             <div id="167df3f0-7059-457a-8bc7-9f7d889c748a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("167df3f0-7059-457a-8bc7-9f7d889c748a")) {
#                     Plotly.newPlot(
#                         '167df3f0-7059-457a-8bc7-9f7d889c748a',
#                         [{"alignmentgroup": "True", "hovertemplate": "object_type=%{x}<br>object_name=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["\u043c\u0430\u0433\u0430\u0437\u0438\u043d (\u043e\u0442\u0434\u0435\u043b \u043a\u0443\u043b\u0438\u043d\u0430\u0440\u0438\u0438)", "\u0437\u0430\u043a\u0443\u0441\u043e\u0447\u043d\u0430\u044f", "\u043a\u0430\u0444\u0435\u0442\u0435\u0440\u0438\u0439", "\u0431\u0443\u0444\u0435\u0442", "\u0431\u0430\u0440", "\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f", "\u0441\u0442\u043e\u043b\u043e\u0432\u0430\u044f", "\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d", "\u043a\u0430\u0444\u0435"], "xaxis": "x", "y": [273, 337, 379, 498, 828, 1867, 2260, 2267, 5768], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# Похоже с большим отрывом лидирует кафе - 5768 мест, следующий ресторан и столовая с 2268 и 2264 мест соответственно

# %%
# Исследуем соотношение сетевых и несетевых заведений по количеству.
chain = rest_data.groupby('chain',as_index=False).object_name.count()

print(chain.loc[0,'object_name']/chain.loc[1,'object_name'])
ax=sns.barplot(data=chain,x='chain',y='object_name')
ax.set_title('Кол-во сетевых и не сетевых заведений')
ax.set_xlabel('Сеть?')
ax.set_ylabel('Кол-во заведений')
plt.show()
# Out:
# 3.8842780026990553

# %% [markdown]
# Количество сетевых заведений почти в 4 раза меньше не сетевых.

# %%
#Определим для какого вида объекта общественного питания характерно сетевое распространение?

chain_type = rest_data.groupby(['object_type','chain'],as_index=False).object_name.count()
plt.figure(figsize=(12,5))
ax=sns.barplot(data=chain_type,x='object_type',y='object_name',hue='chain')
ax.set_title('Кол-во сетевых и не сетевых заведений по типам')
ax.set_xlabel('Тип заведения')
ax.set_ylabel('Кол-во заведений')
plt.xticks(rotation=70)
plt.show()

# %%
# посмотрим на доли 
chain_sum = chain_type.groupby('object_type',as_index=False).object_name.sum()
chain_sum.columns = ['object_type','sum']
chain_type = chain_type.merge(chain_sum, on = 'object_type')
chain_type['ratio'] = chain_type['object_name']/chain_type['sum']

# %%
plt.figure(figsize=(12,5))
ax=sns.barplot(data=chain_type,x='object_type',y='ratio',hue='chain')
ax.set_title('Доля сетевых и не сетевых заведений по типам')
ax.set_xlabel('Тип заведения')
ax.set_ylabel('Доля заведений')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# <b>Сетевой формат более характерен для предприятий быстрого обслуживания

# %%
#Оценим что характерно для сетевых заведений: много заведений с небольшим числом посадочных мест в каждом или
# мало заведений с большим количеством посадочных мест?
only_chain = rest_data.query('chain == True')
only_chain_grouped = only_chain.groupby('new_name').agg({'chain':'count','number':'mean'}).rename(columns={'chain':'chain_count','number':'avg_capacity'})

sns.jointplot(data = only_chain_grouped, x='chain_count',y='avg_capacity')

print('95% процентиль кол-ва заведений:', np.percentile(only_chain_grouped['chain_count'],95))
print('95% процентиль средней вместимости:', np.percentile(only_chain_grouped['avg_capacity'],95))
print('медиана средней вместимости:', only_chain_grouped['avg_capacity'].median())
# Out:
# 95% процентиль кол-ва заведений: 30.25
# 95% процентиль средней вместимости: 153.93153390388414
# медиана средней вместимости: 44.53703703703704

# %%
# посмотрим как обстоят дела в общей выборке:
all_grouped = rest_data.groupby('new_name').agg({'chain':'count','number':'mean'})
print('95% процентиль:', np.percentile(all_grouped['number'],95))
print('среднее', all_grouped['number'].mean())
print('медиана:', all_grouped['number'].median())
# Out:
# 95% процентиль: 240.0
# среднее 66.82282436780115
# медиана: 43.46153846153846

# %%
fig1, fig2 = plt.subplots(figsize=(12,5))
fig1 = sns.distplot(only_chain_grouped['avg_capacity'],label = 'only chain' )
fig2 = sns.distplot(all_grouped['number'],label = 'all' )
fig1, fig2 = plt.xlim(-10, 300)
plt.title("Вместимость сетевых и не сетевых заведений")
plt.legend()
plt.show()

# %% [markdown]
# <b>Похоже, что в 95% количество сетевых заведений не превышает 30, а кол-во посадочных мест 154. В целом количество посадочных мест в сетевых и не сетевых заведений схоже, но сетевых заведений с большим количеством мест всё же меньше.

# %%
#Для каждого вида объекта общественного питания определим среднее количество посадочных мест.

# %%
cap_types = rest_data.groupby('object_type',as_index=False).number.mean().sort_values(by='number')

fig = px.bar(cap_types, x='object_type', y='number',title='Объекты общественного питания по средней вместимости')
fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_showgrid=False, yaxis_showgrid=False)
fig.show()
# Out:
# <div>
#
#
#             <div id="d6c7aa7a-01b4-4b7c-888c-5803163472b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d6c7aa7a-01b4-4b7c-888c-5803163472b5")) {
#                     Plotly.newPlot(
#                         'd6c7aa7a-01b4-4b7c-888c-5803163472b5',
#                         [{"alignmentgroup": "True", "hovertemplate": "object_type=%{x}<br>number=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["\u043c\u0430\u0433\u0430\u0437\u0438\u043d (\u043e\u0442\u0434\u0435\u043b \u043a\u0443\u043b\u0438\u043d\u0430\u0440\u0438\u0438)", "\u0437\u0430\u043a\u0443\u0441\u043e\u0447\u043d\u0430\u044f", "\u043a\u0430\u0444\u0435\u0442\u0435\u0440\u0438\u0439", "\u043f\u0440\u0435\u0434\u043f\u0440\u0438\u044f\u0442\u0438\u0435 \u0431\u044b\u0441\u0442\u0440\u043e\u0433\u043e \u043e\u0431\u0441\u043b\u0443\u0436\u0438\u0432\u0430\u043d\u0438\u044f", "\u043a\u0430\u0444\u0435", "\u0431\u0430\u0440", "\u0431\u0443\u0444\u0435\u0442", "\u0440\u0435\u0441\u0442\u043e\u0440\u0430\u043d", "\u0441\u0442\u043e\u043b\u043e\u0432\u0430\u044f"], "xaxis": "x", "y": [5.589743589743589, 7.940652818991098, 9.174142480211081, 21.01071237279057, 40.40794036061026, 44.138888888888886, 54.55421686746988, 97.06572562858403, 137.85398230088495], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %% [markdown]
# Лидирует столовая.

# %%
#Выделим в отдельный столбец информацию об улице из столбца address .
# воспользуемся регулярными выражениями
regex = "(^[-\w ]+шоссе|^проезд[-\w ]+|^[-\w ]+улица|[-\w ]+улица|улица[-\w ]+|[-\w ]+набережная|деревня[-\w ]+|\
[-\w ]+переулок|[-\w ]+тупик|[-\w ]+шоссе|[-\w ]+площадь|поселение[-\w ]+|площадь[-\w ]+|проспект[-\w ]+|[-\w ]+бульвар|\
[-\w ]+проезд|[-\w ]+проспект|бульвар[-\w ]+|город Зеленоград|[-\w ]+проезд|[-\w ]+аллея|шоссе[-\w ]+|\
аллея[-\w ]+|микрорайон[-\w ]+|переулок[-\w ]+|проезд[-\w ]+|[0-9]-й квартал[-\w ]+|[0-9]-й микрорайон?[-\w ]+),"
rest_data['new_address'] = rest_data['address'].str.extract(pat=regex)[0]


print('нераспознанных улиц:', rest_data['new_address'].isna().sum())
# Out:
# нераспознанных улиц: 93

# %%
#удалим нераспознанные строки <1%
rest_data.dropna(inplace=True)
rest_data.reset_index(drop=True,inplace=True)

#удалим лишние пробелы
rest_data['new_address'] = rest_data['new_address'].apply(lambda x: x.strip())
rest_data.sample(5)
# Out:
#            object_name  chain  \
# 14185            cofix   True
# 11132         суши wok   True
# 11053  чайхона баракат  False
# 1141          иссыкуль  False
# 7938          север-юг  False
#
#                                                  address  number  \
# 14185  город Москва, Ленинградское шоссе, дом 16А, ст...       0
# 11132      город Москва, бульвар Дмитрия Донского, дом 1       0
# 11053  город Москва, Новодмитровская улица, дом 2, ко...      44
# 1141   город Москва, Тихорецкий бульвар, дом 2, корпус 1      40
# 7938              город Москва, Страстной бульвар, дом 2      60
#
#                              object_type      new_name  \
# 14185                          кафетерий         cofix
# 11132  предприятие быстрого обслуживания      суши wok
# 11053                               кафе  чайхона акат
# 1141                                кафе      иссыкуль
# 7938                            ресторан       северюг
#
#                     new_address
# 14185       Ленинградское шоссе
# 11132  бульвар Дмитрия Донского
# 11053     Новодмитровская улица
# 1141         Тихорецкий бульвар
# 7938          Страстной бульвар

# %%
#Построим график топ-10 улиц по количеству объектов общественного питания. 
#Воспользуемся внешней информацией и определим в каких районах Москвы находятся эти улицы.

top_streets = rest_data.groupby('new_address', as_index=False).new_name.count().sort_values(by='new_name',ascending=False).head(10)


plt.figure(figsize=(12,5))
ax = sns.barplot(data=top_streets,x='new_address',y='new_name',palette="pastel")
ax.set_title('топ-10 улиц по количеству объектов общественного питания')
ax.set_xlabel('Улица')
ax.set_ylabel('Кол-во заведений')
plt.xticks(rotation=70)

plt.show()

# %%
#воспользуемся внешними данными (МОСГАЗ) по улицам и районам
districts = pd.read_csv('mosgaz-streets.csv')
#объединим с нашими улицами
top_streets = top_streets.merge(districts, left_on = 'new_address',right_on = 'streetname')[['new_address','new_name','area','okrug']]
new_top_streets = top_streets.groupby('new_address',as_index=False).agg({'new_name':'first','area':'first','okrug':'first'}).sort_values(by='new_name',ascending=False)
new_top_streets
# Out:
#               new_address  new_name                         area       okrug
# 6        город Зеленоград       231                Район Крюково  Зеленоград
# 8           проспект Мира       199           Алексеевский район        СВАО
# 5       Профсоюзная улица       178          Академический район        ЮЗАО
# 2  Ленинградский проспект       172               Район Аэропорт         САО
# 4  Пресненская набережная       167            Пресненский район         ЦАО
# 0        Варшавское шоссе       154  Район Чертаново Центральное         ЮАО
# 3      Ленинский проспект       147   Район Проспект Вернадского         ЗАО
# 7    проспект Вернадского       116   Район Проспект Вернадского         ЗАО
# 1    Кутузовский проспект       113           Район Дорогомилово         ЗАО

# %% [markdown]
# похоже для Сосенского поселения района не нашлось

# %%
#Найдем число улиц с одним объектом общественного питания. 
bottom_streets = rest_data.groupby('new_address', as_index=False).new_name.count().query('new_name == 1')
bottom_streets = bottom_streets.merge(districts, left_on='new_address',right_on='streetname')

# %%
new_bottom_streets = bottom_streets.groupby('new_address',as_index=False).agg({'area':'first'})[['new_address','area']]
areas = new_bottom_streets.groupby('area',as_index=False).agg({'new_address':'count'})

print('ТОП 10 районов с одинокими улицами:')
areas.sort_values(by='new_address',ascending=False).head(10)
# Out:
# ТОП 10 районов с одинокими улицами:
#                    area  new_address
# 91      Таганский район           26
# 3       Басманный район           24
# 18    Пресненский район           21
# 76      Район Хамовники           21
# 92       Тверской район           20
# 19          Район Арбат           14
# 13      Мещанский район           12
# 43      Район Лефортово           12
# 30  Район Замоскворечье           11
# 85   Район Южное Бутово           10

# %%
#Посмотрим на распределение количества посадочных мест для улиц с большим количеством объектов общественного питания.

top_street_array = np.array(new_top_streets.reset_index()['new_address'])
top_streets_objects = rest_data.query('new_address in @top_street_array').reset_index()

fig1, fig2 = plt.subplots(figsize=(12,5))
fig1 = sns.distplot(top_streets_objects['number'],label = 'TOP streets')
fig2 = sns.distplot(all_grouped['number'],label = 'all streets' )
fig1, fig2 = plt.xlim(-10, 300)
plt.title("Вместимость всех и ТОП улиц")
plt.legend()
plt.show()

# %%
top_streets_objects = top_streets_objects.merge(new_top_streets, how='left', on = 'new_address')
top_streets_objects['ok_address'] =  top_streets_objects['new_address']+' '+top_streets_objects['okrug']

print('медиана среди ТОП улиц:', top_streets_objects['number'].median())

plt.figure(figsize=(15,5))
sns.boxplot(data = top_streets_objects,x='ok_address',y='number')
plt.xticks(rotation=20)
plt.ylim(0, 300)
plt.show()
# Out:
# медиана среди ТОП улиц: 40.0

# %% [markdown]
# Похоже, что на ТОП улицах обычно не много посадочных мест. Медианное значение 40, и в основном на каждой улице в половине заведений менее 100 мест. Вероятне всего, причина по которой эти улицы имеют большое кол-во заведений, это их протяженность и большое количество небольших заведений вдоль них.
# Отдельно стоит выделить Пресненскую набережную рядом с Москва-Сити - единственная улица из ЦАО. Небольшое кол-во посадочных мест скорее всего из-за очень дорогой аренды, а разнообразие связано с большим количеством офисных работников в этом районе.

# %% [markdown]
# ### Общий вывод:
# Небольшое кафе - самый популярный вид заведения в Москве, при этом доля сетевх заведений в этом сегменте только 20%. Обыно вместимость кафе в районе 40 посадочных мест. Исходя из анализа расположений, возможно лучший вариант для нашего кафе будет Пресненская набережная - формат небольшого кафе знаком местным обитателям, большие инвестиции в кафе соответствуют статусу Москва-Сити, а роботы, наконец, смогут разнообразить жизнь местных клерков.

# %% [markdown]
# #### Шаг №3. Подготовка презентации
# Презентация: <a href="https://docs.google.com/presentation/d/16FIZPmJt18wcGzLSOivT6vQmrk9qWOMlxQOBjJeZgQI/edit?usp=sharing">ссылка на облачное хранилище с презентацией</a>
